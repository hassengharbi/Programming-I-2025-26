# %%
f=open("My Pyhton Stuff/student.csv", 'r')

# %%
f.readlines()
# Out:
# ['id,first_name,last_name,birthdate,bac_ID,moy_bac\n',
#  '2325,Gabe,Swannack,19/08/2006,b5,11.06\n',
#  '7742,Norrie,Tomkin,23/01/2006,b2,19.41\n',
#  '2592,Gerri,Soan,05/11/2006,b5,18.28\n',
#  '6862,Winny,Scanlin,17/09/2006,b2,9.12\n',
#  '7330,Viole,Humpage,04/02/2006,b4,14.25\n',
#  '1386,Noemi,Bufton,10/01/2007,b6,17.58\n',
#  '0753,Susi,Edsall,05/01/2007,b3,10.41\n',
#  '0611,Hillery,Mateuszczyk,24/01/2007,b5,15.86\n',
#  '0862,Marguerite,Ruprecht,08/07/2006,b6,17.88\n',
#  '7678,Nevins,Kemmons,30/07/2006,b6,18.41\n',
#  '6425,Shayne,Brendeke,17/10/2006,b4,12.6\n',
#  '3713,Nancee,Gosford,13/07/2006,b6,14.91\n',
#  '7043,Sharl,Elsegood,06/03/2006,b1,14.33\n',
#  '4364,Sydney,Blackston,17/06/2006,b5,12.46\n',
#  '1415,Janessa,Bletcher,24/12/2006,b2,9.26\n',
#  '8945,Dalston,Jeays,15/09/2006,b5,9.21\n',
#  '8572,Kaitlyn,Wilkins,30/12/2006,b1,19.57\n',
#  '5655,Dud,Daburn,15/05/2006,b6,17.89\n',
#  '2143,Florentia,Snalham,08/03/2006,b4,17.39\n',
# ...
