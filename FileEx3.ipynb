# %%
def countryID():
    try:
        f=open('country.csv','r')
        i =f.read()
        line = i.split(',')
        print(line)
        f.close()
    except FileNotFoundError:
                  print('file does not exist')

# %%
countryID()
# Out:
# ['country_ID', 'country_name', 'last_name', 'email', 'gender', 'ip_address\nc1', 'Spain', 'Dubery', 'gdubery0@hhs.gov', 'Polygender', '144.86.52.53\nc2', 'France', 'Gerling', 'agerling1@feedburner.com', 'Female', '70.203.12.241\nc3', 'France', 'Janz', 'cjanz2@yellowbook.com', 'Male', '143.98.218.1\nc4', 'France', 'Dowson', 'ldowson3@earthlink.net', 'Male', '113.129.15.187\nc5', 'Argentina', 'Wilfling', 'lwilfling4@nifty.com', 'Female', '227.79.55.255\n']

# %% [markdown]
# ## split() function

# %% [markdown]
# Python String split() method splits a string into a list of strings after breaking the given string by the specified separator.

# %%
string = "Hello and Good Luck"
words = string.split()
print(words)
# Out:
# ['Hello', 'and', 'Good', 'Luck']

# %%
string = "one,two,three"
words = string.split(',')
print(words)
# Out:
# ['one', 'two', 'three']
